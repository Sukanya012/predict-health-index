# %%
# Import libraries
#pip install sodapy

import requests as res
import pandas as pd
from sodapy import Socrata

# %% [markdown]
# ### Step 1: Problem statement

# %% [markdown]
# PROBLEM: To identify emerging health problems in US amoung adults and to inform development and implementation of effective, targeted public health prevention activities.
#
# SOLUTION: To provide quality health estimates for 500 cities in the US by providing data estimates for 27 measures of chronic disease related to unhealthy behaviors (5), health outcomes (13), and use of preventive services (9) and focus their efforts to improve Health.
#
# DATASOURCE: Data sources used to generate these measures include:
#
# . Behavioral Risk Factor Surveillance System (BRFSS) data (2017, 2016), \n
# . Census Bureau 2010 census population data, and
# . American Community Survey (ACS) 2013-2017, 2012-2016 estimates
# We are using structured dataset we have obtained from CDC website
#
# PREDICTING:Emerging Health Problems in 500 cities in the US.
#
# FEATURES:State, CityName, GeoLocation, Population Count,caterory,measure,Crude Prevalance
#
# TARGET: datavalue
#
# We are using a supervised model and trying to predict using regression model.
#
# we are using multiple features such as the city/census tract, measures of cronic illness,population count to define the target.

# %% [markdown]
# ### Step 2: Data Acquisition

# %% [markdown]
# DataSource : https://chronicdata.cdc.gov/500-Cities-Places/500-Cities-Local-Data-for-Better-Health-2019-relea/6vp6-wxuq

# %%
#https://dev.socrata.com/foundry/chronicdata.cdc.gov/6vp6-wxuq
#API to download data
client = Socrata("chronicdata.cdc.gov", None)
results = client.get("6vp6-wxuq", limit = 810200)
chronicdata = pd.DataFrame.from_records(results)
chronicdata.to_csv('500_Cities__Local_Data_for_Better_Health.csv')
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
#read chronic data
chronicdata_df = pd.read_csv('500_Cities__Local_Data_for_Better_Health.csv')   
chronicdata_df.head()
# Out:
#    Unnamed: 0  year stateabbr   statedesc   cityname geographiclevel  \
# 0           0  2017        CA  California  Hawthorne    Census Tract
# 1           1  2017        CA  California  Hawthorne            City
# 2           2  2017        CA  California    Hayward            City
# 3           3  2017        CA  California    Hayward            City
# 4           4  2017        CA  California      Hemet            City
#
#   datasource             category             uniqueid  \
# 0      BRFSS      Health Outcomes  0632548-06037602504
# 1      BRFSS  Unhealthy Behaviors              0632548
# 2      BRFSS      Health Outcomes              0633000
# 3      BRFSS  Unhealthy Behaviors              0633000
# 4      BRFSS           Prevention              0633182
#
#                                              measure  ...  \
# 0             Arthritis among adults aged >=18 Years  ...
# 1       Current smoking among adults aged >=18 Years  ...
# 2  Coronary heart disease among adults aged >=18 ...  ...
# 3               Obesity among adults aged >=18 Years  ...
# 4  Cholesterol screening among adults aged >=18 Y...  ...
#
#                                          geolocation categoryid   measureid  \
# 0  {'latitude': '33.905547923', 'longitude': '-11...    HLTHOUT   ARTHRITIS
# 1  {'latitude': '33.914667701', 'longitude': '-11...     UNHBEH    CSMOKING
# 2  {'latitude': '37.6329591551', 'longitude': '-1...    HLTHOUT         CHD
# 3  {'latitude': '37.6329591551', 'longitude': '-1...     UNHBEH     OBESITY
# 4  {'latitude': '33.7352277311', 'longitude': '-1...    PREVENT  CHOLSCREEN
#
#    cityfips     tractfips     short_question_text  \
# 0  632548.0  6.037603e+09               Arthritis
# 1  632548.0           NaN         Current Smoking
# 2  633000.0           NaN  Coronary Heart Disease
# 3  633000.0           NaN                 Obesity
# 4  633182.0           NaN   Cholesterol Screening
#
#    :@computed_region_bxsw_vy29 :@computed_region_he4y_prf8  \
# 0                          8.0                      1195.0
# 1                          8.0                      1195.0
# 2                          8.0                      1141.0
# 3                          8.0                      1141.0
# 4                          8.0                      1177.0
#
#   data_value_footnote_symbol data_value_footnote
# 0                        NaN                 NaN
# 1                        NaN                 NaN
# 2                        NaN                 NaN
# 3                        NaN                 NaN
# 4                        NaN                 NaN
#
# [5 rows x 27 columns]

# %% [markdown]
# ### Step 3: Data Dictionary

# %% [markdown]
# | original column name       | column name           | description                       | datatype   |
# |----------------------------|-----------------------|-----------------------------------|------------|
# | Year                       | year                  | year                              | int        |
# | StateAbbr                  | state                 | state abbrevation                 | string     |
# | StateDesc                  | state_name            | state name                        | string     |
# | CityName                   | city_name             | city name                         | string     |
# | GeographicalLevel          | geographical_level    | US/City/Census Tract              | string     |
# | DataSource                 | data_source           | data_source                       | string     |
# | Category                   | category              | topic                             | string     |
# | UniqueId                   | unique_id             | cityFIPS/tractFIPS                | string     |
# | Measure                    | measure               | measure full name                 | string     |
# | Data_Value_Unit            | unit                  | data value unit % for percent     | string     |
# | DataValueTypeID            | data_type_id          | identifier for data value type    | string     |
# | Data_Value_Type            | data_type             | data type                         | string     |
# | Data_Value                 | data                  | data value                        | int        |
# | Low_Confidence_Limit       | low_confidence_limit  | low confidence limit              | int        |
# | High_Confidence_Limit      | high_confidence_limit | high confidence limit             | int        |
# | Data_Value_Footnote_Symbol | footnote_symbol       | footnote symbol                   | string     |
# | Data_Value_Footnote        | footnote_text         | footnote text                     | string     |
# | PopulationCount            | population_count      | population count from census 2020 | int        |
# | GeoLocation                | geolocation           | latitude and longitude            | dictionary |
# | CategoryID                 | category              | identifier for topic              | string     |
# | MeasureID                  | measure               | measure identifier                | string     |
# | cityFIPS                   | city_fips             | FIPS code                         | string     |
# | TractFIPS                  | tract_fips            | FIPS code                         | string     |
# | Short_Question_Text        | measure_name          | measure short name                | string     |

# %% [markdown]
# Step 4: Feature Extraction
# Structured Dataset

# %% [markdown]
# Step 5: Data cleaning

# %%
#dropping columns not needed
df1=chronicdata.drop(columns=['year', 'statedesc', 'datasource', 'measure','data_value_unit', 'data_value_footnote', 'data_value_type', 'low_confidence_limit', 'high_confidence_limit', 'data_value_footnote_symbol', 'categoryid', 'short_question_text'])
df1
# dropping all rows with any Null/NaN/NaT Values
df2=df1.dropna()
df2
# Out:
#        stateabbr    cityname geographiclevel             category  \
# 0             CA   Hawthorne    Census Tract      Health Outcomes
# 5             CA       Indio    Census Tract      Health Outcomes
# 8             CA   Inglewood    Census Tract      Health Outcomes
# 15            AL      Hoover    Census Tract           Prevention
# 18            AL  Huntsville    Census Tract      Health Outcomes
# ...          ...         ...             ...                  ...
# 810096        WA   Vancouver    Census Tract      Health Outcomes
# 810098        WI     Madison    Census Tract      Health Outcomes
# 810099        WA      Tacoma    Census Tract           Prevention
# 810100        WA   Vancouver    Census Tract      Health Outcomes
# 810101        WI    Appleton    Census Tract  Unhealthy Behaviors
#
#                    uniqueid datavaluetypeid data_value populationcount  \
# 0       0632548-06037602504          CrdPrv       14.6            4407
# 5       0636448-06065045213          CrdPrv       22.0            5006
# 8       0636546-06037601801          CrdPrv       12.7            2472
# 15      0135896-01073014302          CrdPrv       81.9            1636
# 18      0137000-01089002922          CrdPrv        9.3            4387
# ...                     ...             ...        ...             ...
# 810096  5374060-53011041011          CrdPrv       24.2            2994
# 810098  5548000-55025000202          CrdPrv        3.8            3016
# 810099  5370000-53053061900          CrdPrv       74.2            1961
# 810100  5374060-53011041331          CrdPrv       28.1            2565
# 810101  5502375-55087010200          CrdPrv       27.0            4048
#
#                                               geolocation   measureid  \
# 0       {'latitude': '33.905547923', 'longitude': '-11...   ARTHRITIS
# 5       {'latitude': '33.7144617083', 'longitude': '-1...   ARTHRITIS
# 8       {'latitude': '33.9439711273', 'longitude': '-1...    DIABETES
# 15      {'latitude': '33.3923792867', 'longitude': '-8...    MAMMOUSE
# 18      {'latitude': '34.612755588', 'longitude': '-86...    DIABETES
# ...                                                   ...         ...
# 810096  {'latitude': '45.658182142', 'longitude': '-12...   ARTHRITIS
# 810098  {'latitude': '43.0683437287', 'longitude': '-8...        COPD
# 810099  {'latitude': '47.2276735186', 'longitude': '-1...  CHOLSCREEN
# 810100  {'latitude': '45.6495869118', 'longitude': '-1...    HIGHCHOL
# 810101  {'latitude': '44.2675274909', 'longitude': '-8...       BINGE
#
#        cityfips    tractfips :@computed_region_bxsw_vy29  \
# 0       0632548  06037602504                           8
# 5       0636448  06065045213                           8
# 8       0636546  06037601801                           8
# 15      0135896  01073014302                          29
# 18      0137000  01089002922                          29
# ...         ...          ...                         ...
# 810096  5374060  53011041011                           6
# 810098  5548000  55025000202                          41
# 810099  5370000  53053061900                           6
# 810100  5374060  53011041331                           6
# 810101  5502375  55087010200                          41
#
#        :@computed_region_he4y_prf8
# 0                             1195
# 5                             1177
# 8                             1195
# 15                            1583
# 18                            1588
# ...                            ...
# 810096                        2977
# 810098                         867
# 810099                        3210
# 810100                        2977
# 810101                        3032
#
# [739557 rows x 14 columns]
